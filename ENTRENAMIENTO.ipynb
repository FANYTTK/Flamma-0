# %% [markdown]
# <a href="https://colab.research.google.com/github/FANYTTK/Flamma-0/blob/main/ENTRENAMIENTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'modis_2023_Mexico.csv', 'sample_data']

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'modis_2023_Mexico.csv', 'sample_data']

# %%
import pandas as pd

# Cargar el archivo (Colab lo guarda en '/content/')
df = pd.read_csv("/content/modis_2023_Mexico.csv")

# Mostrar las primeras filas
df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   17.9036   -92.4803       304.9   3.8    1.8  2023-01-01       725
# 1   16.2050   -95.1697       324.5   1.0    1.0  2023-01-01      1955
# 2   17.8925   -93.1889       314.1   1.2    1.1  2023-01-01      1955
# 3   17.8719   -92.4901       310.3   1.3    1.1  2023-01-01      1955
# 4   17.9142   -93.4310       329.3   1.1    1.1  2023-01-01      1955
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0      Aqua      MODIS          62    61.03       280.4  55.4        N     2
# 1      Aqua      MODIS          67    61.03       306.6  11.0        D     2
# 2      Aqua      MODIS          58    61.03       294.4   9.2        D     2
# 3      Aqua      MODIS           0    61.03       293.9   7.1        D     2
# 4      Aqua      MODIS          84    61.03       295.1  28.3        D     0

# %%
from google.colab import files

# Esto abrirá un cuadro de diálogo para subir archivos
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25658487-443d-409f-831d-a4fa98181d30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25658487-443d-409f-831d-a4fa98181d30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Lee tu archivo subido, por ejemplo un CSV
df = pd.read_csv('/content/modis_2023_Mexico.csv')

# Muestra las primeras filas para revisar los datos
print(df.head())
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   17.9036   -92.4803       304.9   3.8    1.8  2023-01-01       725
# 1   16.2050   -95.1697       324.5   1.0    1.0  2023-01-01      1955
# 2   17.8925   -93.1889       314.1   1.2    1.1  2023-01-01      1955
# 3   17.8719   -92.4901       310.3   1.3    1.1  2023-01-01      1955
# 4   17.9142   -93.4310       329.3   1.1    1.1  2023-01-01      1955
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0      Aqua      MODIS          62    61.03       280.4  55.4        N     2
# 1      Aqua      MODIS          67    61.03       306.6  11.0        D     2
# 2      Aqua      MODIS          58    61.03       294.4   9.2        D     2
# 3      Aqua      MODIS           0    61.03       293.9   7.1        D     2
# 4      Aqua      MODIS          84    61.03       295.1  28.3        D     0

# %%
# Ejemplo de normalización (si es necesario)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = df.drop('etiqueta', axis=1).values  # Asegúrate de que la columna 'etiqueta' sea la variable que quieres predecir
X_scaled = scaler.fit_transform(X)

y = df['etiqueta'].values  # Etiquetas de salida

# %%
print(df.columns)
# Out:
# Index(['latitude', 'longitude', 'brightness', 'scan', 'track', 'acq_date',
#        'acq_time', 'satellite', 'instrument', 'confidence', 'version',
#        'bright_t31', 'frp', 'daynight', 'type'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c2f65e0c72bf> in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
#
# NameError: name 'X_scaled' is not defined
